# %%
import numpy as np
import pandas as pd

# %%
file = pd.read_csv('data_e.g.csv')

# %%
file = pd.DataFrame(file)
file
# Out:
#     Unnamed: 0    ID  Building  Year of sale  Month of sale Type of property  \
# 0          NaN  1030         1        2005.0           11.0        Apartment
# 1          NaN  1029         1        2005.0           10.0        Apartment
# 2          NaN  2002         2        2007.0            7.0        Apartment
# 3          NaN  2031         2        2007.0           12.0        Apartment
# 4          NaN  1049         1        2004.0           11.0        Apartment
# ..         ...   ...       ...           ...            ...              ...
# 262        NaN  5044         5           NaN            NaN        Apartment
# 263        NaN  5047         5           NaN            NaN        Apartment
# 264        NaN  5048         5           NaN            NaN        Apartment
# 265        NaN  5050         5           NaN            NaN        Apartment
# 266        NaN  5051         5           NaN            NaN        Apartment
#
# ...

# %%
file.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Building', 'Year of sale', 'Month of sale',
#        'Type of property', 'Property #', 'Area (ft.)', 'Price', 'Status',
#        'Unnamed: 10', 'Customer ID', 'Entity', 'Name', 'Surname',
#        'Age at time of purchase', 'Interval', 'Y', 'M', 'D', 'Gender',
#        'Country', 'State', 'Purpose', 'Deal satisfaction', 'Mortgage',
#        'Source'],
#       dtype='object')

# %%
del file['Unnamed: 0']

# %%
file.rename(columns={'Year of sale':"Year_of_sale","Month of sale":"Month_of_sale","Type of property":"Type_of_property",
                     "Property #":"Property","Area (ft.)":"Area_in_ft","Customer ID":"Customer_ID","Age at time of purchase":
                    "Age_at_time_of_purchase","Deal satisfaction":"Deal_satisfaction"},inplace=True)

# %%
file.dtypes
# Out:
# ID                           int64
# Building                     int64
# Year_of_sale               float64
# Month_of_sale              float64
# Type_of_property            object
# Property                     int64
# Area_in_ft                 float64
# Price                       object
# Status                      object
# Unnamed: 10                float64
# Customer_ID                 object
# Entity                      object
# Name                        object
# Surname                     object
# Age_at_time_of_purchase     object
# Interval                    object
# Y                          float64
# M                          float64
# D                          float64
# Gender                      object
# Country                     object
# State                       object
# Purpose                     object
# Deal_satisfaction          float64
# Mortgage                    object
# Source                      object
# dtype: object

# %%
file.Year_of_sale=file.Year_of_sale.fillna(0).astype('int')

# %%
file.Year_of_sale
# Out:
# 0      2005
# 1      2005
# 2      2007
# 3      2007
# 4      2004
#        ...
# 262       0
# 263       0
# 264       0
# 265       0
# 266       0
# Name: Year_of_sale, Length: 267, dtype: int32

# %%
file.Month_of_sale
# Out:
# 0      11.0
# 1      10.0
# 2       7.0
# 3      12.0
# 4      11.0
#        ...
# 262     NaN
# 263     NaN
# 264     NaN
# 265     NaN
# 266     NaN
# Name: Month_of_sale, Length: 267, dtype: float64

# %%
file.Month_of_sale = file.Month_of_sale.fillna(0).astype('int')

# %%
file.Month_of_sale
# Out:
# 0      11
# 1      10
# 2       7
# 3      12
# 4      11
#        ..
# 262     0
# 263     0
# 264     0
# 265     0
# 266     0
# Name: Month_of_sale, Length: 267, dtype: int32

# %%
#file = file.columns

file.Price[0]
# Out:
# '$246,172.68 '

# %%
def check(val):
    if ',' in val.Price:
        newval=val.Price.split(',')
        newval=newval[0]+newval[1]
    newval=newval[1:]    
    return float(newval)    
file.Price=file.apply(check,axis='columns')

# %%
file.Price
# Out:
# 0      246172.68
# 1      246331.90
# 2      209280.91
# 3      452667.01
# 4      467083.31
#          ...
# 262    322610.74
# 263    279191.26
# 264    287996.53
# 265    365868.78
# 266    199216.40
# Name: Price, Length: 267, dtype: float64

# %%
file
# Out:
#        ID  Building  Year_of_sale  Month_of_sale Type_of_property  Property  \
# 0    1030         1          2005             11        Apartment        30
# 1    1029         1          2005             10        Apartment        29
# 2    2002         2          2007              7        Apartment         2
# 3    2031         2          2007             12        Apartment        31
# 4    1049         1          2004             11        Apartment        49
# ..    ...       ...           ...            ...              ...       ...
# 262  5044         5             0              0        Apartment        44
# 263  5047         5             0              0        Apartment        47
# 264  5048         5             0              0        Apartment        48
# 265  5050         5             0              0        Apartment        50
# 266  5051         5             0              0        Apartment        51
#
# ...

# %%
newdata=file[:197]

# %%
newdata.groupby('Gender').Gender.count()
# Out:
# Gender
# F     70
# M    108
# Name: Gender, dtype: int64

# %%
gender=pd.DataFrame(newdata.groupby('Gender').Gender.count())

# %%
gender
# Out:
#         Gender
# Gender
# F           70
# M          108

# %%
gender.rename(columns={"Gender":"Frequency"},inplace=True)

# %%
gender.plot(y="Frequency",kind="pie",autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
newdata.Gender.fillna("Firm",inplace=True)
# Out:
# C:\Users\R02-PC9\anaconda3\lib\site-packages\pandas\core\series.py:4517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
file.State.value_counts()
# Out:
# California    118
# Nevada         17
# Oregon         11
# Colorado       11
# Arizona        10
# Utah            6
# Virginia        4
# Wyoming         1
# Kansas          1
# Name: State, dtype: int64

# %%
state_data=pd.DataFrame(file.State.value_counts())

# %%
state_data.rename(columns={"State":"Frequency"},inplace=True)

# %%
state_data
# Out:
#             Frequency
# California        118
# Nevada             17
# Oregon             11
# Colorado           11
# Arizona            10
# Utah                6
# Virginia            4
# Wyoming             1
# Kansas              1

# %%
file.groupby('Country')['Country'].count()
# Out:
# Country
# Belgium      2
# Canada       7
# Denmark      1
# Germany      1
# Mexico       1
# Russia       4
# UK           2
# USA        165
# USA         12
# Name: Country, dtype: int64

# %%
file['Country']=file['Country'].str.strip()

# %%
file.groupby('Country')['Country'].count()
# Out:
# Country
# Belgium      2
# Canada       7
# Denmark      1
# Germany      1
# Mexico       1
# Russia       4
# UK           2
# USA        177
# Name: Country, dtype: int64

# %%
state_data["R.F"]=round(state_data.Frequency/state_data.Frequency.sum()*100)

# %%
state_data
# Out:
#             Frequency   R.F
# California        118  66.0
# Nevada             17   9.0
# Oregon             11   6.0
# Colorado           11   6.0
# Arizona            10   6.0
# Utah                6   3.0
# Virginia            4   2.0
# Wyoming             1   1.0
# Kansas              1   1.0

# %%
state_data["C.F"]=state_data['R.F'].cumsum()

# %%
state_data
# Out:
#             Frequency   R.F    C.F
# California        118  66.0   66.0
# Nevada             17   9.0   75.0
# Oregon             11   6.0   81.0
# Colorado           11   6.0   87.0
# Arizona            10   6.0   93.0
# Utah                6   3.0   96.0
# Virginia            4   2.0   98.0
# Wyoming             1   1.0   99.0
# Kansas              1   1.0  100.0

# %%
state_data["USA_Rf"]=round(state_data.Frequency/177*100)

# %%
state_data["USA_cf"]=state_data['USA_Rf'].cumsum()
